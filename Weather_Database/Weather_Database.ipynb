# %%
#Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate a set of 2,000 latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes in a list.
coordinates = list(lats_lngs)

# %%
# import the citipy module.
from citipy import citipy

# %%
#Create a list for holding the names of cities.
cities = []
#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 772

# %%
# Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ef4f573deb6234c0deff1a98f65f8a3

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc,})
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# 7 | grindavik
# Processing Record 12 of Set 7 | miquelon
# Processing Record 13 of Set 7 | beidao
# Processing Record 14 of Set 7 | isla mujeres
# Processing Record 15 of Set 7 | arraial do cabo
# Processing Record 16 of Set 7 | half moon bay
# Processing Record 17 of Set 7 | santa rosa
# Processing Record 18 of Set 7 | port elizabeth
# Processing Record 19 of Set 7 | petropavlovka
# Processing Record 20 of Set 7 | campos
# Processing Record 21 of Set 7 | yenagoa
# Processing Record 22 of Set 7 | thinadhoo
# Processing Record 23 of Set 7 | pacific grove
# Processing Record 24 of Set 7 | abnub
# Processing Record 25 of Set 7 | codrington
# Processing Record 26 of Set 7 | grants pass
# Processing Record 27 of Set 7 | vicosa
# Processing Record 28 of Set 7 | mackay
# Processing Record 29 of Set 7 | minden
# Processing Record 30 of Set 7 | husavik
# Processing Record 31 of Set 7 | dikson
# Processing Record 32 of Set 7 | payson
# Processing Record 33 of Set 7 | riyadh
# Processing Record 34 of Set 7 | dryden
# Processing Record 35 of Set 7 | san cristobal
# Processing Record 36 of Set 7 | eureka
# Processing Record 37 of Set 7 | mehamn
# Processing Record 38 of Set 7 | huarmey
# Processing Record 39 of Set 7 | yantal
# Processing Record 40 of Set 7 | mombetsu
# Processing Record 41 of Set 7 | mecca
# Processing Record 42 of Set 7 | oron
# Processing Record 43 of Set 7 | tepusteca
# Processing Record 44 of Set 7 | sabha
# Processing Record 45 of Set 7 | barberton
# Processing Record 46 of Set 7 | waipawa
# Processing Record 47 of Set 7 | raychikhinsk
# Processing Record 48 of Set 7 | eufaula
# Processing Record 49 of Set 7 | isangel
# Processing Record 50 of Set 7 | bandar-e lengeh
# Processing Record 1 of Set 8 | magalia
# Processing Record 2 of Set 8 | victoria
# Processing Record 3 of Set 8 | kavieng
# Processing Record 4 of Set 8 | maniitsoq
# Processing Record 5 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 8 | honiara
# Processing Record 7 of Set 8 | blythe
# Processing Record 8 of Set 8 | ambagarh chauki
# Processing Record 9 of Set 8 | bojnurd
# Processing Record 10 of Set 8 | nadym
# Processing Record 11 of Set 8 | umarkot
# Processing Record 12 of Set 8 | pasni
# Processing Record 13 of Set 8 | denpasar
# Processing Record 14 of Set 8 | havelock
# Processing Record 15 of Set 8 | ankang
# Processing Record 16 of Set 8 | demyansk
# Processing Record 17 of Set 8 | lac du bonnet
# Processing Record 18 of Set 8 | pangody
# Processing Record 19 of Set 8 | nador
# Processing Record 20 of Set 8 | bodden town
# Processing Record 21 of Set 8 | nacala
# Processing Record 22 of Set 8 | taguatinga
# Processing Record 23 of Set 8 | saurimo
# Processing Record 24 of Set 8 | riosucio
# Processing Record 25 of Set 8 | sao paulo de olivenca
# Processing Record 26 of Set 8 | kapit
# Processing Record 27 of Set 8 | beringovskiy
# Processing Record 28 of Set 8 | manta
# Processing Record 29 of Set 8 | macusani
# Processing Record 30 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 31 of Set 8 | saint-augustin
# Processing Record 32 of Set 8 | ewa beach
# Processing Record 33 of Set 8 | varadero
# Processing Record 34 of Set 8 | pangnirtung
# Processing Record 35 of Set 8 | benguela
# Processing Record 36 of Set 8 | abu samrah
# Processing Record 37 of Set 8 | warri
# Processing Record 38 of Set 8 | okato
# Processing Record 39 of Set 8 | basar
# Processing Record 40 of Set 8 | soyo
# Processing Record 41 of Set 8 | jujuy
# City not found. Skipping...
# Processing Record 42 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 8 | komsomolskiy
# Processing Record 44 of Set 8 | bijapur
# Processing Record 45 of Set 8 | iquira
# Processing Record 46 of Set 8 | harper
# Processing Record 47 of Set 8 | manggar
# Processing Record 48 of Set 8 | manicore
# Processing Record 49 of Set 8 | manokwari
# Processing Record 50 of Set 8 | santa cruz de tenerife
# Processing Record 1 of Set 9 | plettenberg bay
# Processing Record 2 of Set 9 | ternate
# Processing Record 3 of Set 9 | pochutla
# Processing Record 4 of Set 9 | ahipara
# Processing Record 5 of Set 9 | faya
# Processing Record 6 of Set 9 | sarangani
# Processing Record 7 of Set 9 | marzuq
# Processing Record 8 of Set 9 | ureki
# Processing Record 9 of Set 9 | eyl
# Processing Record 10 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 11 of Set 9 | brainerd
# Processing Record 12 of Set 9 | willowmore
# Processing Record 13 of Set 9 | jacksonville
# Processing Record 14 of Set 9 | mpophomeni
# Processing Record 15 of Set 9 | belaya gora
# Processing Record 16 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 9 | kirkwall
# Processing Record 18 of Set 9 | northam
# Processing Record 19 of Set 9 | kalachinsk
# Processing Record 20 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 21 of Set 9 | taoudenni
# Processing Record 22 of Set 9 | cayenne
# Processing Record 23 of Set 9 | dzilam gonzalez
# Processing Record 24 of Set 9 | ulety
# Processing Record 25 of Set 9 | vostok
# Processing Record 26 of Set 9 | gilbues
# Processing Record 27 of Set 9 | valday
# Processing Record 28 of Set 9 | kansanshi
# Processing Record 29 of Set 9 | chopinzinho
# Processing Record 30 of Set 9 | pathein
# Processing Record 31 of Set 9 | praia
# Processing Record 32 of Set 9 | linares
# Processing Record 33 of Set 9 | altar
# Processing Record 34 of Set 9 | san buenaventura
# Processing Record 35 of Set 9 | drumheller
# Processing Record 36 of Set 9 | provideniya
# Processing Record 37 of Set 9 | zyryanka
# Processing Record 38 of Set 9 | bikaner
# Processing Record 39 of Set 9 | saint-joseph
# Processing Record 40 of Set 9 | zaraza
# Processing Record 41 of Set 9 | jian
# Processing Record 42 of Set 9 | qinzhou
# Processing Record 43 of Set 9 | san pedro
# Processing Record 44 of Set 9 | ruiz
# Processing Record 45 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 46 of Set 9 | strezhevoy
# Processing Record 47 of Set 9 | phanat nikhom
# Processing Record 48 of Set 9 | sao borja
# Processing Record 49 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 9 | bertoua
# Processing Record 1 of Set 10 | folldal
# Processing Record 2 of Set 10 | aras
# Processing Record 3 of Set 10 | hervey bay
# Processing Record 4 of Set 10 | salinas
# Processing Record 5 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 7 of Set 10 | luderitz
# Processing Record 8 of Set 10 | ayan
# Processing Record 9 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 10 | gladstone
# Processing Record 11 of Set 10 | yacuiba
# Processing Record 12 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 10 | zlobin
# Processing Record 14 of Set 10 | zhigansk
# Processing Record 15 of Set 10 | port lincoln
# Processing Record 16 of Set 10 | millville
# Processing Record 17 of Set 10 | yaan
# Processing Record 18 of Set 10 | punta alta
# Processing Record 19 of Set 10 | green valley
# Processing Record 20 of Set 10 | asfi
# Processing Record 21 of Set 10 | tarhunah
# City not found. Skipping...
# Processing Record 22 of Set 10 | svetlyy
# Processing Record 23 of Set 10 | port hedland
# Processing Record 24 of Set 10 | cortez
# Processing Record 25 of Set 10 | solnechnyy
# Processing Record 26 of Set 10 | lockhart
# Processing Record 27 of Set 10 | batagay-alyta
# Processing Record 28 of Set 10 | tomatlan
# Processing Record 29 of Set 10 | tingo maria
# Processing Record 30 of Set 10 | west wendover
# Processing Record 31 of Set 10 | guicheng
# City not found. Skipping...
# Processing Record 32 of Set 10 | cockburn town
# Processing Record 33 of Set 10 | bonavista
# Processing Record 34 of Set 10 | russell
# Processing Record 35 of Set 10 | ixtapa
# Processing Record 36 of Set 10 | amga
# Processing Record 37 of Set 10 | karratha
# Processing Record 38 of Set 10 | nago
# Processing Record 39 of Set 10 | itsukaichi
# Processing Record 40 of Set 10 | moyale
# Processing Record 41 of Set 10 | maloy
# Processing Record 42 of Set 10 | lagoa
# Processing Record 43 of Set 10 | ugoofaaru
# Processing Record 44 of Set 10 | canto do buriti
# Processing Record 45 of Set 10 | manadhoo
# Processing Record 46 of Set 10 | bantry
# Processing Record 47 of Set 10 | jerantut
# Processing Record 48 of Set 10 | sitka
# Processing Record 49 of Set 10 | middelkerke
# Processing Record 50 of Set 10 | belawan
# Processing Record 1 of Set 11 | kincardine
# Processing Record 2 of Set 11 | mujiayingzi
# Processing Record 3 of Set 11 | wuwei
# Processing Record 4 of Set 11 | nemuro
# Processing Record 5 of Set 11 | homer
# Processing Record 6 of Set 11 | balkhash
# Processing Record 7 of Set 11 | immokalee
# Processing Record 8 of Set 11 | coquimbo
# Processing Record 9 of Set 11 | hofn
# Processing Record 10 of Set 11 | olafsvik
# Processing Record 11 of Set 11 | boende
# Processing Record 12 of Set 11 | sakakah
# Processing Record 13 of Set 11 | manoel urbano
# Processing Record 14 of Set 11 | rantepao
# Processing Record 15 of Set 11 | paz de ariporo
# City not found. Skipping...
# Processing Record 16 of Set 11 | leningradskiy
# Processing Record 17 of Set 11 | ovsyanka
# Processing Record 18 of Set 11 | gezing
# Processing Record 19 of Set 11 | margate
# Processing Record 20 of Set 11 | stirion
# Processing Record 21 of Set 11 | salamanca
# Processing Record 22 of Set 11 | uinskoye
# Processing Record 23 of Set 11 | makakilo city
# Processing Record 24 of Set 11 | abengourou
# Processing Record 25 of Set 11 | makat
# Processing Record 26 of Set 11 | seymchan
# Processing Record 27 of Set 11 | myre
# Processing Record 28 of Set 11 | san quintin
# Processing Record 29 of Set 11 | sao filipe
# Processing Record 30 of Set 11 | dunda
# Processing Record 31 of Set 11 | cikupa
# Processing Record 32 of Set 11 | nola
# Processing Record 33 of Set 11 | muisne
# Processing Record 34 of Set 11 | zhoukou
# Processing Record 35 of Set 11 | portland
# Processing Record 36 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 11 | qaqortoq
# Processing Record 38 of Set 11 | college
# Processing Record 39 of Set 11 | olinda
# Processing Record 40 of Set 11 | la ciotat
# Processing Record 41 of Set 11 | atherton
# Processing Record 42 of Set 11 | zholymbet
# Processing Record 43 of Set 11 | utete
# Processing Record 44 of Set 11 | rio branco
# Processing Record 45 of Set 11 | port macquarie
# Processing Record 46 of Set 11 | caruray
# Processing Record 47 of Set 11 | slavutych
# Processing Record 48 of Set 11 | liwale
# Processing Record 49 of Set 11 | sile
# Processing Record 50 of Set 11 | khorixas
# Processing Record 1 of Set 12 | qui nhon
# Processing Record 2 of Set 12 | tari
# Processing Record 3 of Set 12 | matagami
# Processing Record 4 of Set 12 | amethi
# Processing Record 5 of Set 12 | igarka
# Processing Record 6 of Set 12 | otjimbingwe
# Processing Record 7 of Set 12 | boa vista
# Processing Record 8 of Set 12 | maneadero
# Processing Record 9 of Set 12 | doaba
# Processing Record 10 of Set 12 | shalakusha
# Processing Record 11 of Set 12 | kencong
# Processing Record 12 of Set 12 | flin flon
# Processing Record 13 of Set 12 | satellite beach
# Processing Record 14 of Set 12 | nortelandia
# Processing Record 15 of Set 12 | manbij
# Processing Record 16 of Set 12 | kjollefjord
# Processing Record 17 of Set 12 | akureyri
# Processing Record 18 of Set 12 | aksay
# Processing Record 19 of Set 12 | hawkesbury
# Processing Record 20 of Set 12 | talaya
# Processing Record 21 of Set 12 | hurghada
# Processing Record 22 of Set 12 | marawi
# Processing Record 23 of Set 12 | ponta delgada
# Processing Record 24 of Set 12 | korla
# Processing Record 25 of Set 12 | lata
# Processing Record 26 of Set 12 | gwanda
# Processing Record 27 of Set 12 | tyrma
# Processing Record 28 of Set 12 | tsagan aman
# Processing Record 29 of Set 12 | evora
# Processing Record 30 of Set 12 | pringsewu
# Processing Record 31 of Set 12 | alabaster
# Processing Record 32 of Set 12 | havoysund
# Processing Record 33 of Set 12 | agadez
# Processing Record 34 of Set 12 | goure
# Processing Record 35 of Set 12 | skibbereen
# Processing Record 36 of Set 12 | kralendijk
# Processing Record 37 of Set 12 | hue
# Processing Record 38 of Set 12 | zalantun
# Processing Record 39 of Set 12 | vondrozo
# Processing Record 40 of Set 12 | gawler
# Processing Record 41 of Set 12 | bereda
# Processing Record 42 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 43 of Set 12 | omaruru
# Processing Record 44 of Set 12 | palizada
# Processing Record 45 of Set 12 | esil
# Processing Record 46 of Set 12 | nipawin
# Processing Record 47 of Set 12 | arkhara
# Processing Record 48 of Set 12 | shimoda
# Processing Record 49 of Set 12 | potosi
# Processing Record 50 of Set 12 | hasaki
# Processing Record 1 of Set 13 | megion
# Processing Record 2 of Set 13 | san felipe
# Processing Record 3 of Set 13 | kurmanayevka
# Processing Record 4 of Set 13 | avanigadda
# Processing Record 5 of Set 13 | harboore
# Processing Record 6 of Set 13 | bouna
# Processing Record 7 of Set 13 | duz
# City not found. Skipping...
# Processing Record 8 of Set 13 | noyabrsk
# Processing Record 9 of Set 13 | khandbari
# Processing Record 10 of Set 13 | turukhansk
# Processing Record 11 of Set 13 | tual
# Processing Record 12 of Set 13 | manama
# Processing Record 13 of Set 13 | alofi
# Processing Record 14 of Set 13 | latung
# Processing Record 15 of Set 13 | ancud
# Processing Record 16 of Set 13 | oktyabrskoye
# Processing Record 17 of Set 13 | kerema
# Processing Record 18 of Set 13 | svetlaya
# Processing Record 19 of Set 13 | hoshcha
# Processing Record 20 of Set 13 | garissa
# Processing Record 21 of Set 13 | gimli
# Processing Record 22 of Set 13 | le moule
# Processing Record 23 of Set 13 | mastung
# Processing Record 24 of Set 13 | katobu
# Processing Record 25 of Set 13 | djambala
# Processing Record 26 of Set 13 | henties bay
# Processing Record 27 of Set 13 | bac lieu
# Processing Record 28 of Set 13 | saravan
# Processing Record 29 of Set 13 | senj
# Processing Record 30 of Set 13 | gambela
# Processing Record 31 of Set 13 | dongsheng
# Processing Record 32 of Set 13 | abancay
# Processing Record 33 of Set 13 | aberdeen
# Processing Record 34 of Set 13 | ararat
# Processing Record 35 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 13 | dwarahat
# Processing Record 37 of Set 13 | baracoa
# Processing Record 38 of Set 13 | matara
# Processing Record 39 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 40 of Set 13 | ikwiriri
# Processing Record 41 of Set 13 | nava
# Processing Record 42 of Set 13 | la ronge
# Processing Record 43 of Set 13 | rabat
# Processing Record 44 of Set 13 | richards bay
# Processing Record 45 of Set 13 | rabo de peixe
# Processing Record 46 of Set 13 | okhotsk
# Processing Record 47 of Set 13 | abatskoye
# Processing Record 48 of Set 13 | nuuk
# Processing Record 49 of Set 13 | taywarah
# Processing Record 50 of Set 13 | luanda
# Processing Record 1 of Set 14 | tres arroyos
# Processing Record 2 of Set 14 | maidens
# Processing Record 3 of Set 14 | kilmez
# City not found. Skipping...
# Processing Record 4 of Set 14 | plerin
# Processing Record 5 of Set 14 | nizwa
# Processing Record 6 of Set 14 | ashford
# Processing Record 7 of Set 14 | la asuncion
# Processing Record 8 of Set 14 | dunedin
# Processing Record 9 of Set 14 | bako
# Processing Record 10 of Set 14 | sayyan
# Processing Record 11 of Set 14 | rumford
# Processing Record 12 of Set 14 | bulgan
# Processing Record 13 of Set 14 | hukuntsi
# Processing Record 14 of Set 14 | kashi
# Processing Record 15 of Set 14 | san ignacio
# Processing Record 16 of Set 14 | omsukchan
# Processing Record 17 of Set 14 | aporawan
# City not found. Skipping...
# Processing Record 18 of Set 14 | yuci
# Processing Record 19 of Set 14 | minab
# Processing Record 20 of Set 14 | pitimbu
# Processing Record 21 of Set 14 | changping
# Processing Record 22 of Set 14 | mapiri
# Processing Record 23 of Set 14 | xining
# Processing Record 24 of Set 14 | tukrah
# Processing Record 25 of Set 14 | witu
# Processing Record 26 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 27 of Set 14 | lar gerd
# City not found. Skipping...
# Processing Record 28 of Set 14 | sobolevo
# Processing Record 29 of Set 14 | komatipoort
# Processing Record 30 of Set 14 | kalmunai
# Processing Record 31 of Set 14 | ertil
# Processing Record 32 of Set 14 | vangaindrano
# Processing Record 33 of Set 14 | tooele
# Processing Record 34 of Set 14 | north bend
# Processing Record 35 of Set 14 | yatou
# Processing Record 36 of Set 14 | plouzane
# Processing Record 37 of Set 14 | sept-iles
# Processing Record 38 of Set 14 | rocha
# Processing Record 39 of Set 14 | honningsvag
# Processing Record 40 of Set 14 | ulundi
# Processing Record 41 of Set 14 | bukachacha
# Processing Record 42 of Set 14 | gravdal
# Processing Record 43 of Set 14 | gobabis
# Processing Record 44 of Set 14 | semme
# Processing Record 45 of Set 14 | iturama
# Processing Record 46 of Set 14 | san jeronimo
# Processing Record 47 of Set 14 | monte gordo
# Processing Record 48 of Set 14 | abu dhabi
# Processing Record 49 of Set 14 | kimbe
# Processing Record 50 of Set 14 | laguna
# Processing Record 1 of Set 15 | dzhebariki-khaya
# Processing Record 2 of Set 15 | kindu
# Processing Record 3 of Set 15 | bronnoysund
# Processing Record 4 of Set 15 | fredericton
# Processing Record 5 of Set 15 | touros
# Processing Record 6 of Set 15 | linjiang
# Processing Record 7 of Set 15 | mersing
# Processing Record 8 of Set 15 | manaure
# Processing Record 9 of Set 15 | alakurtti
# Processing Record 10 of Set 15 | kopayhorod
# Processing Record 11 of Set 15 | puerto escondido
# Processing Record 12 of Set 15 | ratnagiri
# Processing Record 13 of Set 15 | bilibino
# Processing Record 14 of Set 15 | antofagasta
# Processing Record 15 of Set 15 | iroquois falls
# Processing Record 16 of Set 15 | artsyz
# Processing Record 17 of Set 15 | shelton
# Processing Record 18 of Set 15 | mandiana
# Processing Record 19 of Set 15 | tanete
# Processing Record 20 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 21 of Set 15 | zhezkazgan
# Processing Record 22 of Set 15 | barkhan
# Processing Record 23 of Set 15 | deputatskiy
# Processing Record 24 of Set 15 | sorland
# Processing Record 25 of Set 15 | mao
# Processing Record 26 of Set 15 | gizo
# Processing Record 27 of Set 15 | westport
# Processing Record 28 of Set 15 | dali
# Processing Record 29 of Set 15 | kathmandu
# Processing Record 30 of Set 15 | manzhouli
# Processing Record 31 of Set 15 | ampanihy
# Processing Record 32 of Set 15 | dangriga
# Processing Record 33 of Set 15 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 34 of Set 15 | adrasmon
# Processing Record 35 of Set 15 | magadi
# Processing Record 36 of Set 15 | motema
# Processing Record 37 of Set 15 | ayna
# Processing Record 38 of Set 15 | gombe
# Processing Record 39 of Set 15 | saint-pierre
# Processing Record 40 of Set 15 | ostrovnoy
# Processing Record 41 of Set 15 | taybad
# Processing Record 42 of Set 15 | shahumyan
# Processing Record 43 of Set 15 | ketchikan
# Processing Record 44 of Set 15 | swan hill
# Processing Record 45 of Set 15 | vidim
# Processing Record 46 of Set 15 | teknaf
# Processing Record 47 of Set 15 | vestmannaeyjar
# Processing Record 48 of Set 15 | port moresby
# Processing Record 49 of Set 15 | umm lajj
# Processing Record 50 of Set 15 | maua
# Processing Record 1 of Set 16 | sheridan
# Processing Record 2 of Set 16 | mazamari
# Processing Record 3 of Set 16 | hearst
# Processing Record 4 of Set 16 | chekmagush
# Processing Record 5 of Set 16 | kenai
# Processing Record 6 of Set 16 | donja dubica
# Processing Record 7 of Set 16 | bahia honda
# Processing Record 8 of Set 16 | foam lake
# Processing Record 9 of Set 16 | plymouth
# Processing Record 10 of Set 16 | mount pleasant
# Processing Record 11 of Set 16 | puno
# Processing Record 12 of Set 16 | klyuchi
# Processing Record 13 of Set 16 | mawlamyine
# Processing Record 14 of Set 16 | yima
# Processing Record 15 of Set 16 | hay river
# Processing Record 16 of Set 16 | vardo
# Processing Record 17 of Set 16 | sembe
# Processing Record 18 of Set 16 | yumen
# Processing Record 19 of Set 16 | haines junction
# Processing Record 20 of Set 16 | progreso
# Processing Record 21 of Set 16 | rorvik
# Processing Record 22 of Set 16 | chalisgaon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0                 Torbay      NE  47.6666  -52.7314     30.00        93
# 1                Mataura      NE -46.1927  168.8643     48.00        80
# 2                Winslow      NE  35.0242 -110.6974     21.20        79
# 3  Los Llanos De Aridane      NE  28.6585  -17.9182     68.00        68
# 4               Culiacan      NE  24.7994 -107.3897     66.99        82
# 5                   Nome      NE  64.5011 -165.4064     -9.40        64
# 6           Puerto Ayora      NE  -0.7393  -90.3518     82.40        69
# 7                Jojoima      NE   7.8792  -10.7878     96.73        29
# 8                 Cairns      NE -16.9167  145.7667     75.20        83
# 9                Ushuaia      NE -54.8000  -68.3000     51.80        62
#
#    Cloudiness  Wind Speed Current Description
# 0          90       21.85     overcast clouds
# 1          23        8.01          few clouds
# 2           1        4.03           clear sky
# 3          40       13.80    scattered clouds
# 4           1        2.04           clear sky
# 5           1        5.75           clear sky
# 6           0       11.50           clear sky
# 7          20        2.30          few clouds
# 8         100        5.70     overcast clouds
# 9          40       23.02    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
